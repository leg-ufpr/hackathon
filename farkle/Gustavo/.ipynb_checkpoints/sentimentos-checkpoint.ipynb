# %%
import pandas as pd
import numpy as np
import json 
from unidecode import unidecode

# %%
js = np.array(json.load(open('../hackathon/opinioes.json')))
df = pd.read_csv('../hackathon/notas.csv',sep=';')

# %% [markdown]
# sadfgh

# %%
df
# Out:
#              ID             quesito  nota
# 0      e2b9dc08              Estilo     7
# 1      e2b9dc08          Acabamento     5
# 2      e2b9dc08  Posição de dirigir     7
# 3      e2b9dc08        Instrumentos    10
# 4      e2b9dc08            Interior     5
# 5      e2b9dc08         Porta-malas     5
# 6      e2b9dc08          Desempenho    10
# 7      e2b9dc08               Motor    10
# 8      e2b9dc08              Câmbio    10
# 9      e2b9dc08              Freios    10
# 10     e2b9dc08           Suspensão    10
# 11     e2b9dc08             Consumo    10
# 12     e2b9dc08        Estabilidade    10
# 13     e2b9dc08     Custo-Benefício    10
# 14     e2b9dc08        Recomendação    10
# 15     3b9dcf63              Estilo    10
# 16     3b9dcf63          Acabamento     8
# 17     3b9dcf63  Posição de dirigir     8
# 18     3b9dcf63        Instrumentos     8
# 19     3b9dcf63            Interior     6
# 20     3b9dcf63         Porta-malas     6
# 21     3b9dcf63          Desempenho     8
# 22     3b9dcf63               Motor    10
# 23     3b9dcf63              Câmbio    10
# 24     3b9dcf63              Freios    10
# 25     3b9dcf63           Suspensão     8
# 26     3b9dcf63             Consumo    10
# 27     3b9dcf63        Estabilidade     8
# 28     3b9dcf63     Custo-Benefício    10
# 29     3b9dcf63        Recomendação    10
# ...         ...                 ...   ...
# 79905  1e4ff70a              Estilo    10
# 79906  1e4ff70a          Acabamento     9
# 79907  1e4ff70a  Posição de dirigir    10
# 79908  1e4ff70a        Instrumentos    10
# 79909  1e4ff70a            Interior     8
# 79910  1e4ff70a         Porta-malas     6
# 79911  1e4ff70a          Desempenho    10
# 79912  1e4ff70a               Motor    10
# 79913  1e4ff70a              Câmbio    10
# 79914  1e4ff70a              Freios    10
# 79915  1e4ff70a           Suspensão    10
# 79916  1e4ff70a             Consumo    10
# 79917  1e4ff70a        Estabilidade    10
# 79918  1e4ff70a     Custo-Benefício    10
# 79919  1e4ff70a        Recomendação    10
# 79920  7a5f0318              Estilo     9
# 79921  7a5f0318          Acabamento     8
# 79922  7a5f0318  Posição de dirigir     8
# 79923  7a5f0318        Instrumentos    10
# 79924  7a5f0318            Interior     8
# 79925  7a5f0318         Porta-malas     7
# 79926  7a5f0318          Desempenho     9
# 79927  7a5f0318               Motor     9
# 79928  7a5f0318              Câmbio     9
# 79929  7a5f0318              Freios     7
# 79930  7a5f0318           Suspensão     9
# 79931  7a5f0318             Consumo    10
# 79932  7a5f0318        Estabilidade    10
# 79933  7a5f0318     Custo-Benefício     8
# 79934  7a5f0318        Recomendação     8
#
# [79935 rows x 3 columns]
